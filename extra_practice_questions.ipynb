# %% [markdown]
# # Python Practice Notebook
#
# ## 50 Deep-Thinking Exercises
#
# Instructions:
# - Read each question carefully.
# - Break the problem into steps before coding.
# - Focus on clarity and clean logic.
# - Avoid unnecessary shortcuts.
# - Test your code with different inputs.
#
# `The questions are intentionally left vague to encourage deep thinking and personal research`

# %% [markdown]
# ## Q1 – Financial Calculation
# Create variables for principal, rate, and time. Calculate simple interest and total amount.

# %%
# Write your solution here

# %% [markdown]
# ## Q2 – Dynamic Value Rotation
# Rotate values of three variables without hardcoding numbers.

# %%
# Write your solution here

# %% [markdown]
# ## Q3 – Distance Formula
# Calculate distance between two coordinate points.

# %%
# Write your solution here

# %% [markdown]
# ## Q4 – Time Converter
# Convert total minutes into hours and remaining minutes.

# %%
# Write your solution here

# %% [markdown]
# ## Q5 – Divisibility Check
# Check if a number is divisible by both 4 and 6.

# %%
# Write your solution here

# %% [markdown]
# ## Q6 – Manual Absolute Value
# Compute absolute value without using abs().

# %%
# Write your solution here

# %% [markdown]
# ## Q7 – Reverse Without Slicing
# Reverse a string using a loop.

# %%
# Write your solution here

# %% [markdown]
# ## Q8 – Character Frequency
# Count frequency of each character in a string.

# %%
# Write your solution here

# %% [markdown]
# ## Q9 – Password Strength Checker
# Validate password strength using conditions.

# %%
# Write your solution here

# %% [markdown]
# ## Q10 – Remove Duplicate Characters
# Remove repeated characters while preserving order.

# %%
# Write your solution here

# %% [markdown]
# ## Q11 – Word Count Analyzer
# Count total words and compute average word length.

# %%
# Write your solution here

# %% [markdown]
# ## Q12 – Find Longest Word
# Find the longest word in a paragraph.

# %%
# Write your solution here

# %% [markdown]
# ## Q13 – Manual Title Case
# Capitalize first letter of each word manually.

# %%
# Write your solution here

# %% [markdown]
# ## Q14 – Remove Duplicates From List
# Remove duplicates without using set().

# %%
# Write your solution here

# %% [markdown]
# ## Q15 – Second Largest Number
# Find second largest number without sorting.

# %%
# Write your solution here

# %% [markdown]
# ## Q16 – Running Total
# Create cumulative sum list.

# %%
# Write your solution here

# %% [markdown]
# ## Q17 – Prime Counter
# Count how many numbers in a list are prime.

# %%
# Write your solution here

# %% [markdown]
# ## Q18 – Split Positives & Negatives
# Separate positive and negative numbers.

# %%
# Write your solution here

# %% [markdown]
# ## Q19 – Manual List Rotation
# Rotate list one step to the right.

# %%
# Write your solution here

# %% [markdown]
# ## Q20 – Frequency of Elements
# Count frequency of each element in a list.

# %%
# Write your solution here

# %% [markdown]
# ## Q21 – List Intersection
# Find common elements without using set().

# %%
# Write your solution here

# %% [markdown]
# ## Q22 – Student Average Calculator
# Compute average marks for each student.

# %%
# Write your solution here

# %% [markdown]
# ## Q23 – Highest Performing Student
# Determine student with highest average.

# %%
# Write your solution here

# %% [markdown]
# ## Q24 – Dictionary Inversion
# Swap keys and values.

# %%
# Write your solution here

# %% [markdown]
# ## Q25 – Merge Dictionaries
# Merge dictionaries and sum overlapping values.

# %%
# Write your solution here

# %% [markdown]
# ## Q26 – Filter Dictionary
# Remove entries where value < 50.

# %%
# Write your solution here

# %% [markdown]
# ## Q27 – Group Words by Length
# Group words by their length.

# %%
# Write your solution here

# %% [markdown]
# ## Q28 – Inventory Value
# Calculate total inventory value from nested dictionary.

# %%
# Write your solution here

# %% [markdown]
# ## Q29 – Create Dictionary From Lists
# Combine two lists into a dictionary.

# %%
# Write your solution here

# %% [markdown]
# ## Q30 – Number Classifier
# Classify number as positive/negative/even/odd.

# %%
# Write your solution here

# %% [markdown]
# ## Q31 – Leap Year Checker
# Implement leap year logic.

# %%
# Write your solution here

# %% [markdown]
# ## Q32 – Triangle Validator
# Check if three sides form valid triangle.

# %%
# Write your solution here

# %% [markdown]
# ## Q33 – Grading System
# Implement grading classification.

# %%
# Write your solution here

# %% [markdown]
# ## Q34 – ATM Simulation
# Simulate withdrawal logic with balance check.

# %%
# Write your solution here

# %% [markdown]
# ## Q35 – Loan Eligibility
# Check loan eligibility using salary and credit score.

# %%
# Write your solution here

# %% [markdown]
# ## Q36 – Multiplication Table
# Generate multiplication table 1–10.

# %%
# Write your solution here

# %% [markdown]
# ## Q37 – Fibonacci Generator
# Generate first 15 Fibonacci numbers.

# %%
# Write your solution here

# %% [markdown]
# ## Q38 – Longest Increasing Streak
# Find longest increasing sequence length.

# %%
# Write your solution here

# %% [markdown]
# ## Q39 – Count Vowels
# Count vowels in a paragraph.

# %%
# Write your solution here

# %% [markdown]
# ## Q40 – Prime Generator
# Generate prime numbers from 1–100.

# %%
# Write your solution here

# %% [markdown]
# ## Q41 – Pyramid Pattern
# Print star pyramid using nested loops.

# %%
# Write your solution here

# %% [markdown]
# ## Q42 – Guessing Loop
# Loop until correct number is guessed.

# %%
# Write your solution here

# %% [markdown]
# ## Q43 – Matrix Row Sum
# Compute sum of each row in 2D list.

# %%
# Write your solution here

# %% [markdown]
# ## Q44 – Prime Function
# Create is_prime(n) returning True/False.

# %%
# Write your solution here

# %% [markdown]
# ## Q45 – List Analyzer Function
# Return max, min, and average in dictionary.

# %%
# Write your solution here

# %% [markdown]
# ## Q46 – Duplicate Remover Function
# Create function that removes duplicates from list.

# %%
# Write your solution here

# %% [markdown]
# ## Q47 – Safe Divide Function
# Handle division safely with error checks.

# %%
# Write your solution here

# %% [markdown]
# ## Q48 – Student Performance Analyzer
# Return top student, class average, pass count.

# %%
# Write your solution here

# %% [markdown]
# ## Q49 – Text Analyzer Function
# Return total words, unique words, most frequent word.

# %%
# Write your solution here

# %% [markdown]
# ## Q50 – Final Challenge
# Create analyze_numbers(numbers) returning statistics dictionary.

# %%
# Write your solution here
